# %% [markdown]
# TECHNIKI PROGRAMOWANIA - projekt 3

# %% [markdown]
# Szymon Lewicki 203253 Przemysław Olszewski 2

# %%
import _core as mpl
from IPython.display import Image, display
mpl.plotIMG(2 * mpl.sin(2,0,7,1000), "sin.png", "sinus(x)", 560, 480)

# %%
display(Image("sin.png"))

# %%
mpl.plotIMG(mpl.cos(0.9,0,7,1000), "cos.png", "cosinus(x)", 560, 480)

# %%
display(Image("cos.png"))

# %%
mpl.plotIMG(mpl.sqrwave(3.2,0,7,1000) * 3, "sqrw.png", "square wave", 560, 480)

# %%
display(Image("sqrw.png"))

# %%
mpl.plotIMG(mpl.sawwave(4.6,0,7,1000), "saww.png", "saw wave", 560, 480)

# %%
display(Image("saww.png"))

# %% [markdown]
# DFT

# %%
freq = 10
samples = 1000
sinus = mpl.sin(freq,0,12.56,samples)
dft_sin = mpl.fourier(sinus,0,12.56,samples)
mpl.plotIMG(dft_sin, "ftsin.png", "DFT of sinus", 560, 480)

# %%
display(Image("ftsin.png"))
